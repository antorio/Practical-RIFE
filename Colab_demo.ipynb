# %%
#: Clone the Practical-RIFE repository from GitHub and install the requirements.
# Note: Make sure to check for the latest repository URL and update if necessary.
# !git clone https://github.com/antorio/Practical-RIFE.git
#!git clone -b codex/review-git-repository-for-analysis --single-branch https://github.com/antorio/Practical-RIFE.git
# %cd Practical-RIFE
# !pip3 install --upgrade pip
# !pip install --upgrade pip setuptools wheel
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu121
# !pip3 install -r requirements.txt

# %%
#downloads the model file from Google Drive using gdown and extract it.
# IMPORTANT: The gdown file ID should be updated with the ID of the file you want to download in the future.
# Also, replace 'RIFE_trained_model_v4.13.2.zip' with the name of the new zip file you're downloading.

#!wget --no-check-certificate 'https://drive.google.com/uc?id=1mj9lH6Be7ztYtHAr1xUUGT3hRtWJBy_5' -O 'RIFE_trained_model_v4.13.2.zip'
#!unzip RIFE_trained_model_v4.13.2.zip

#!wget --no-check-certificate 'https://drive.google.com/uc?id=1octn-UVuEjXa_HlsIUbNeLTTvYCKbC_s' -O 'RIFEv4.18_0703.zip'
#!unzip RIFEv4.18_0703.zip

# !wget --no-check-certificate 'https://drive.google.com/uc?id=1ZKjcbmt1hypiFprJPIKW0Tt0lr_2i7bg' -O 'RIFEv4.25_0919.zip'
# !unzip RIFEv4.25_0919.zip

#!wget --no-check-certificate 'https://drive.google.com/uc?id=1gViYvvQrtETBgU1w8axZSsr7YUuw31uy' -O 'RIFEv4.26_0921.zip'
#!unzip RIFEv4.26_0921.zip

# !wget --no-check-certificate 'https://drive.google.com/uc?id=1vJy82jub1D9O8BZgjPeMu3HHx4bG-NY1' -O 'RIFEv4.26large_1118.zip'
# !unzip RIFEv4.26large_1118.zip

#!wget --no-check-certificate 'https://drive.google.com/uc?id=1PCYRfKwMkymP0V5dmcmGwrKu0lU7xSZ0' -O 'SAFA.zip'
#!unzip SAFA.zip -d train_log_SAFA

# %%
#: Set the XDG_RUNTIME_DIR environment variable to avoid errors in Colab.
import os
os.environ['XDG_RUNTIME_DIR'] = '/tmp'

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
input = "/content/drive/MyDrive/c/FINAL_07.24.41-2.mp4" # @param {type:"string"}
multi = "4" # @param {type:"string"}
#: Execute the video frame interpolation script.
# Replace 'video.mp4' with the name of your video file.
# !python3 inference_video.py --multi={multi} --video={input}
#!python3 inference_video_enhance.py --video={input} --ext=mov --model="train_log_SAFA"

# --img / --video: The input file address
# --output: Output video name 'xxx.mp4'
# --model: Directory with trained model files
# --UHD: It is equivalent to setting scale=0.5
# --montage: Splice the generated video with the original video, like this demo
# --fps: Set output FPS manually
# --ext: Set output video format, default: mp4
# --multi: Interpolation frame rate multiplier
# --exp: Set --multi to 2^(--exp)

# %%
# prompt: disconnect

import os
from google.colab import runtime

def disconnect():
  runtime.unassign()

disconnect()
